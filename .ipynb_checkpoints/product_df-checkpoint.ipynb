# %%
import pandas as pd

# %%
df_name = pd.read_csv('Resources/Body_Bark_ProductService_list.csv')

# %%
df_name.head(20)
# Out:
#                sku                            description
# 0     1001-Black-L               High Neck Tank, Black, L
# 1     1001-Black-M               High Neck Tank, Black, M
# 2     1001-Black-S               High Neck Tank, Black, S
# 3    1001-Black-XL              High Neck Tank, Black, XL
# 4    1001-Black-XS              High Neck Tank, Black, XS
# 5     1001-Ivory-L               High Neck Tank, Ivory, L
# 6     1001-Ivory-M               High Neck Tank, Ivory, M
# 7     1001-Ivory-S               High Neck Tank, Ivory, S
# 8    1001-Ivory-XL              High Neck Tank, Ivory, XL
# 9    1001-Ivory-XS              High Neck Tank, Ivory, XS
# 10    1001-White-L               High Neck Tank, White, L
# 11    1001-White-M               High Neck Tank, White, M
# 12    1001-White-S               High Neck Tank, White, S
# 13   1001-White-XL              High Neck Tank, White, XL
# 14   1001-White-XS              High Neck Tank, White, XS
# ...

# %%
df_name[['product_num','product_color', 'product_size']] = df_name.sku.str.split(pat='-', expand=True)

# %%
df_name.head(20)
# Out:
#                sku                            description product_num  \
# 0     1001-Black-L               High Neck Tank, Black, L        1001
# 1     1001-Black-M               High Neck Tank, Black, M        1001
# 2     1001-Black-S               High Neck Tank, Black, S        1001
# 3    1001-Black-XL              High Neck Tank, Black, XL        1001
# 4    1001-Black-XS              High Neck Tank, Black, XS        1001
# 5     1001-Ivory-L               High Neck Tank, Ivory, L        1001
# 6     1001-Ivory-M               High Neck Tank, Ivory, M        1001
# 7     1001-Ivory-S               High Neck Tank, Ivory, S        1001
# 8    1001-Ivory-XL              High Neck Tank, Ivory, XL        1001
# 9    1001-Ivory-XS              High Neck Tank, Ivory, XS        1001
# 10    1001-White-L               High Neck Tank, White, L        1001
# 11    1001-White-M               High Neck Tank, White, M        1001
# ...

# %%
product_df=df_name
